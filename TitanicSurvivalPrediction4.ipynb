# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/TitanicSurvivalPrediction4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('Titanic Dataset.csv')

data.head(5)

data.isnull().sum()

age_q1 = np.quantile(data['Age'], 0.25)
age_q2 = np.quantile(data['Age'], 0.50)
age_q3 = np.quantile(data['Age'], 0.75)

print("Age Quartiles -")
print("Q1 -", age_q1)
print("Q2 -", age_q2)
print("Q3 -", age_q3)

IQR_age = age_q3 - age_q1
print("Interquartile Range :", IQR_age)

plt.hist(data['Age'])
plt.ylabel("Count of Passengers")
plt.xlabel("Age")

fare_q1 = np.quantile(data['Fare'], 0.25)
fare_q2 = np.quantile(data['Fare'], 0.50)
fare_q3 = np.quantile(data['Fare'], 0.75)

print("Fare Quartiles -")
print("Q1 -", fare_q1)
print("Q2 -", fare_q2)
print("Q3 -", fare_q3)

IQR_fare = fare_q3 - fare_q1
print("Interquartile Range :", IQR_fare)

bins =np.arange(0,250,20)
plt.hist(data['Fare'], bins=np.arange(1,250, 20))
plt.ylabel("Count of Passengers")
plt.xlabel("Fare")
plt.xticks(bins)
# Out:
# Age Quartiles -
# Q1 - 20.0
# Q2 - 27.76173076923077
# Q3 - 33.0
# Interquartile Range : 13.0
# Fare Quartiles -
# Q1 - 8.05
# Q2 - 15.05
# Q3 - 30.3833
# Interquartile Range : 22.333299999999998
# ([<matplotlib.axis.XTick at 0x788ec5559d60>,
#   <matplotlib.axis.XTick at 0x788ec5954800>,
#   <matplotlib.axis.XTick at 0x788ec55b6ff0>,
#   <matplotlib.axis.XTick at 0x788ef1d9baa0>,
#   <matplotlib.axis.XTick at 0x788ef1e246e0>,
#   <matplotlib.axis.XTick at 0x788ef1d9b2f0>,
#   <matplotlib.axis.XTick at 0x788ef1e25580>,
#   <matplotlib.axis.XTick at 0x788ef1e260c0>,
#   <matplotlib.axis.XTick at 0x788ef1e2d4f0>,
#   <matplotlib.axis.XTick at 0x788ef1e2e060>,
#   <matplotlib.axis.XTick at 0x788ef1d9bf20>,
#   <matplotlib.axis.XTick at 0x788ef1e2e8a0>,
#   <matplotlib.axis.XTick at 0x788ef1e30680>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100'),
#   Text(120, 0, '120'),
#   Text(140, 0, '140'),
#   Text(160, 0, '160'),
#   Text(180, 0, '180'),
#   Text(200, 0, '200'),
#   Text(220, 0, '220'),
#   Text(240, 0, '240')])
