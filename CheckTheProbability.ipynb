# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/CheckTheProbability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

probability = 1 / 6

print("Probability of getting a 6:", probability)

dice = random.randint(1, 6)

print("You rolled:", dice)

if dice == 6:
    print("Game can be started!")
else:
    print("Roll again. Best of luck!")
# Out:
# Probability of getting a 6: 0.16666666666666666
# You rolled: 6
# Game can be started!
