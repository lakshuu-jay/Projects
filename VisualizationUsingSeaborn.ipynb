# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/VisualizationUsingSeaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
url = "https://drive.google.com/uc?export=download&id=11uvRoI4eG-6uOmk2KkeOwRyX_AdOlwSS"
df = pd.read_csv(url)

print(df.head())
sns.displot(df["total_bill"])
sns.displot(df["tip"])
sns.displot(df["size"])
plt.show()

sns.histplot(df["total_bill"], kde=True)
plt.title("Total Bill Distribution")
plt.show()
sns.scatterplot(x="total_bill", y="tip", hue="time", data=df)
plt.title("Total Bill vs Tip")
plt.show()

sns.pairplot(df)
plt.show()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
