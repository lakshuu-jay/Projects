# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/LifeExpectancySurvey4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("gapminder(2007).csv")

continent_count = data.groupby('continent').size()

plt.figure(figsize=(7,7))

plt.pie(
    continent_count,
    labels=continent_count.index,
    autopct="%.2f%%",
    labeldistance=1.15,
    wedgeprops={"linewidth":2,"edgecolor":"white"}
)

plt.title("Countries by Continent")
plt.show()
