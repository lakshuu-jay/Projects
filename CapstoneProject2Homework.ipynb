# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/CapstoneProject2Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://drive.google.com/uc?export=download&id=1ZIMKkik1Bjdo3qeXAIE7VrI9XMP1gZ-S"
df = pd.read_csv(url)

print(df.head(3))
print(df.tail(3))

print(df.info())

print(df.isnull().sum())

subset = df.iloc[40:75]
print(subset)

max_votes = df[df["No_of_Votes"] == df["No_of_Votes"].max()]
print(max_votes)

sns.boxplot(x=df["IMDB_Rating"], y=df["Runtime"])
plt.show()

plt.scatter(df["IMDB_Rating"], df["Runtime"])
plt.show()

sns.histplot(df["IMDB_Rating"])
plt.show()

sns.histplot(df["Runtime"])
plt.show()

sns.countplot(x=df["IMDB_Rating"])
plt.show()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 1             The Godfather           1972           A      175
# 2           The Dark Knight           2008          UA      152
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview              Director  \
# 0  Two imprisoned men bond over a number of years...        Frank Darabont
# 1  An organized crime dynasty's aging patriarch t...  Francis Ford Coppola
# 2  When the menace known as the Joker wreaks havo...     Christopher Nolan
#
# ...
