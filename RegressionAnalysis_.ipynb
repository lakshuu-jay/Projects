# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/RegressionAnalysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("xydataset.csv")

x = data.iloc[:, 1]
y = data.iloc[:, 2]
x_mean = np.mean(x)
y_mean = np.mean(y)

m = np.sum((x - x_mean) * (y - y_mean)) / np.sum((x - x_mean) ** 2)

c = y_mean - m * x_mean

print("Slope (m):", m)
print("Intercept (c):", c)
y_pred = m * x + c

plt.scatter(x, y, label="Actual Data")
plt.plot(x, y_pred, label="Regression Line")

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Regression Analysis")
plt.legend()

plt.show()
# Out:
# Slope (m): 1.2873573700109275
# Intercept (c): 9.908606190326715
