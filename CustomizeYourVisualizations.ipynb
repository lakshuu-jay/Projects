# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/CustomizeYourVisualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("FuelConsumption.csv")

df.head()

df.info()

df.isnull().sum()

plt.figure(figsize=(8,5))
sns.set_theme(style="white")
sns.countplot(x="FUELTYPE", data=df, palette="Set2")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.xticks(rotation=45)
plt.title("Count of Fuel Types")
plt.show()

sns.set_theme(style="dark")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="Set2")
plt.xticks(rotation=45)
plt.show()

sns.set_theme(style="whitegrid")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="Set2")
plt.xticks(rotation=45)
plt.show()

sns.set_theme(style="darkgrid")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="Set2")
plt.xticks(rotation=45)
plt.show()

sns.set_theme(style="ticks")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="Set2")
plt.xticks(rotation=45)
plt.show()

sns.set_theme(style="white")
sns.set_context("paper")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="coolwarm")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.xticks(rotation=45)
plt.title("Paper")
plt.show()

sns.set_context("notebook")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="coolwarm")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.xticks(rotation=45)
plt.title("Notebook")
plt.show()

sns.set_context("talk")

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="coolwarm")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.xticks(rotation=45)
plt.title("Talk")
plt.show()

sns.set_context("poster", font_scale=0.8)

plt.figure(figsize=(8,5))
sns.countplot(x="FUELTYPE", data=df, palette="coolwarm")

ax = plt.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.xticks(rotation=45)
plt.title("Poster")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...
