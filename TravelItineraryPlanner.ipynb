# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshuu-jay/Projects/blob/main/TravelItineraryPlanner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv("WeatherDataset.csv")
df.head()
df_group=df.groupby('month').mean()
df_group=df_group.reset_index()

df_group.plot.area(x='month',y="Humidity",alpha=0.6)

plt.plot(df['Temperature (C)'])
plt.ylabel('Temperature(C)')
plt.xlabel('Reading Number over time')
